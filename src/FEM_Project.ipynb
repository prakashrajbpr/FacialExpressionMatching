# %%
import numpy as np
import cv2
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = 'Datasets/train'
val_dir = 'Datasets/test'
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.

# %%
validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()

emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))
# emotion_model.load_weights('emotion_model.h5')
# Out:
# c:\Users\praka\New_Project\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cv2.ocl.setUseOpenCL(False)

emotion_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}

# %%
emotion_model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001, decay=1e-6),
    metrics=['accuracy']
)
# Out:
# c:\Users\praka\New_Project\.venv\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
emotion_model_info = emotion_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=5,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# Epoch 1/5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 103s 229ms/step - accuracy: 0.5152 - loss: 1.2785 - val_accuracy: 0.5266 - val_loss: 1.2437
# Epoch 2/5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5469 - loss: 1.2255 - val_accuracy: 0.5265 - val_loss: 1.2440
# Epoch 3/5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 122s 273ms/step - accuracy: 0.5391 - loss: 1.2319 - val_accuracy: 0.5421 - val_loss: 1.2276
# Epoch 4/5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.5000 - loss: 1.2906 - val_accuracy: 0.5420 - val_loss: 1.2244
# Epoch 5/5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 95s 212ms/step - accuracy: 0.5516 - loss: 1.2004 - val_accuracy: 0.5372 - val_loss: 1.2081

# %%
emotion_model.save_weights('emotion_model.weights.h5')

# %%
emotion_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}

# %%
cv2.ocl.setUseOpenCL(False)
cap = cv2.VideoCapture(0)

# %%
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        break

    # Load Haar Cascade for face detection
    bounding_box = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    num_faces = bounding_box.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in num_faces:
        cv2.rectangle(frame, (x, y - 50), (x + w, y + h + 10), (255, 0, 0), 2)
        roi_gray_frame = gray_frame[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray_frame, (48, 48)), -1), 0)

        # Debugging: Check input image properties
        print("Cropped Image Shape:", cropped_img.shape)
        print("Pixel Range:", np.min(cropped_img), "to", np.max(cropped_img))

        # Predict emotion
        emotion_prediction = emotion_model.predict(cropped_img)
        print("Prediction Probabilities:", emotion_prediction)

        maxindex = int(np.argmax(emotion_prediction))
        print("Predicted Emotion Index:", maxindex)

        # Display emotion label on video
        cv2.putText(frame, emotion_dict[maxindex], (x + 20, y - 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    # Display the resulting frame
    cv2.imshow('Video', cv2.resize(frame, (1200, 860), interpolation=cv2.INTER_CUBIC))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 14 to 206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 9 to 212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 6.0019856e-25
#   0.0000000e+00 0.0000000e+00]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 8 to 204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Prediction Probabilities: [[5.918898e-27 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 0.000000e+00]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 8 to 226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 3.2690734e-13 0.0000000e+00 1.0000000e+00
#   0.0000000e+00 0.0000000e+00]]
# Predicted Emotion Index: 4
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 9 to 201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Prediction Probabilities: [[0.000000e+00 0.000000e+00 1.000000e+00 0.000000e+00 2.216037e-20
#   0.000000e+00 0.000000e+00]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 8 to 221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Prediction Probabilities: [[2.2098201e-31 0.0000000e+00 1.0000000e+00 0.0000000e+00 5.2998068e-32
#   0.0000000e+00 2.5979262e-12]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 8 to 219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Prediction Probabilities: [[7.6252197e-20 0.0000000e+00 6.2967342e-22 1.0000000e+00 2.1535679e-27
#   0.0000000e+00 5.3842595e-37]]
# Predicted Emotion Index: 3
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 8 to 204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 9 to 206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 10 to 208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 8 to 205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Predi
]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Prediction Probabilities: [[0.0000e+00 0.0000e+00 1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00
#   3.9407e-20]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 237
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 4.8235047e-32]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Prediction Probabilities: [[0.00000e+00 0.00000e+00 1.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#   5.23624e-26]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 7 to 228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 2.6978578e-31]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 3.4041613e-30]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 7.2441914e-11]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 1.9585905e-32]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Prediction Probabilities: [[0.000000e+00 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 7.434765e-33]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 1.0484769e-34]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Prediction Probabilities: [[0.000000e+00 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 4.626167e-34]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Prediction Probabilities: [[0.000000e+00 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 8.837225e-33]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 7.3658945e-38]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 2.8607306e-34]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 2.6049512e-28]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 1.6392322e-31]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 2.8516744e-35]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 3.2983543e-24]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Prediction Probabilities: [[0.000000e+00 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 3.868992e-13]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Prediction Probabilities: [[0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00 1.0434072e-31
#   0.0000000e+00 0.0000000e+00]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 4 to 230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 4 to 231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Prediction Probabilities: [[3.0494053e-26 0.0000000e+00 1.0000000e+00 0.0000000e+00 3.2986934e-32
#   0.0000000e+00 0.0000000e+00]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Prediction Probabilities: [[0.000000e+00 0.000000e+00 1.000000e+00 0.000000e+00 7.425138e-38
#   0.000000e+00 0.000000e+00]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 5 to 227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Prediction Probabilities: [[0. 0. 1. 0. 0. 0. 0.]]
# Predicted Emotion Index: 2
# Cropped Image Shape: (1, 48, 48, 1)
# Pixel Range: 6 to 225
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 22
#      19 print("Pixel Range:", np.min(cropped_img), "to", np.max(cropped_img))
#      21 # Predict emotion
# ---> 22 emotion_prediction = emotion_model.predict(cropped_img)
#      23 print("Prediction Probabilities:", emotion_prediction)
#      25 maxindex = int(np.argmax(emotion_prediction))
#
# File c:\Users\praka\New_Project\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\praka\New_Project\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:561, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     559 for step, iterator in epoch_iterator:
#     560     callbacks.on_predict_batch_begin(step)
# --> 561     data = get_data(iterator)
#     562     batch_outputs = self.predict_function(data)
#     563     outputs = append_to_outputs(batch_outputs, outputs)
#
# File c:\Users\praka\New_Project\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:541, in TensorFlowTrainer.predict.<locals>.get_data(iterator)
#     539 for _ in range(self.steps_per_execution):
#     540     try:
# --> 541         single_step_data = next(iterator)
#     542     except (StopIteration, tf.errors.OutOfRangeError) as e:
#     543         if hasattr(data, "__len__") and len(data) > 0:
#     544             # Suppress the error when still have remaining data.
#
# File c:\Users\praka\New_Project\.venv\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:826, in OwnedIterator.__next__(self)
#     824 def __next__(self):
#     825   try:
# --> 826     return self._next_internal()
#     827   except errors.OutOfRangeError:
#     828     raise StopIteration
#
# File c:\Users\praka\New_Project\.venv\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:776, in OwnedIterator._next_internal(self)
#     773 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     774 # to communicate that there is no more data to iterate over.
#     775 with context.execution_mode(context.SYNC):
# --> 776   ret = gen_dataset_ops.iterator_get_next(
#     777       self._iterator_resource,
#     778       output_types=self._flat_output_types,
#     779       output_shapes=self._flat_output_shapes)
#     781   try:
#     782     # Fast path for the case `self._structure` is not a nested structure.
#     783     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File c:\Users\praka\New_Project\.venv\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3108, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3106 if tld.is_eager:
#    3107   try:
# -> 3108     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3109       _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    3110       "output_shapes", output_shapes)
#    3111     return _result
#    3112   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
